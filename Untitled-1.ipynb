# %%
import pandas as pd

df = pd.read_csv("D:\\Downloads\\UFC.csv")

# Data Cleaning
df['date'] = pd.to_datetime(df['date'])
df['r_dob'] = pd.to_datetime(df['r_dob'])
df['b_dob'] = pd.to_datetime(df['b_dob'])
df['age_diff'] = (df['r_dob']-df['b_dob']).dt.days
df['reach_diff'] = df['r_reach']-df['b_reach']
df['is_winner'] = (df['r_name'] == df['winner']).astype(int)

df.head(10)
# Out:
#            event_id                            event_name       date  \
# 0  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 1  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 2  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 3  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 4  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 5  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 6  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 7  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 8  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
# 9  6e380a4d73ab4f0e  UFC Fight Night: Imavov vs. Borralho 2025-09-06
#
#                        location          fight_id           division  \
# 0  Paris, Ile-de-France, France  d14fea43712707f0        lightweight
# 1  Paris, Ile-de-France, France  5bcd8abf6da01dae       middleweight
# 2  Paris, Ile-de-France, France  0149e875b31e57f8  light heavyweight
# 3  Paris, Ile-de-France, France  69b31593175f77ec        lightweight
# 4  Paris, Ile-de-France, France  a47123ae6e048f11       welterweight
# 5  Paris, Ile-de-France, France  4080b4310d82b42d  light heavyweight
# 6  Paris, Ile-de-France, France  b53031bf4bd0a330      featherweight
# 7  Paris, Ile-de-France, France  23dbe713c4294c66        heavyweight
# 8  Paris, Ile-de-France, France  5cd2dd6075fadcce        lightweight
# 9  Paris, Ile-de-France, France  d56a59a4c79cf515       welterweight
#
#    title_fight                method  finish_round  match_time_sec  ...  \
# 0            0            Submission             2             176  ...
# 1            0  Decision - Unanimous             5             300  ...
# 2            0                KO/TKO             1             300  ...
# 3            0                KO/TKO             2             198  ...
# 4            0                KO/TKO             3             122  ...
# 5            0                KO/TKO             1             282  ...
# 6            0  Decision - Unanimous             3             300  ...
# 7            0                KO/TKO             1             123  ...
# 8            0                KO/TKO             1             201  ...
# 9            0                KO/TKO             1              54  ...
#
#    b_str_def b_td_avg b_td_avg_acc b_td_def  b_sub_avg              winner  \
# 0         60     0.00            0       84        0.0  Benoit Saint Denis
# 1         60     1.28           48       76        0.4  Nassourdine Imavov
# 2         43     1.43           18       35        1.3  Modestas Bukauskas
# 3         50     4.17           55       81        0.2         Mason Jones
# 4         47     0.00            0       47        0.0           Axel Sola
# 5         53     0.90           42       18        0.6            Oumar Sy
# 6         57     2.00           33        0        0.0       William Gomis
# 7         55     0.00            0        0        0.0         Ante Delija
# 8         62     1.18          100       76        0.0      Kaue Fernandes
# 9         54     3.91           34       91        0.2  Rinat Fakhretdinov
#
#           winner_id  age_diff  reach_diff  is_winner
# 0  c2299ec916bc7c56    -182.0       -5.08          1
# 1  881bf86d4cba8578    1140.0        0.00          1
# 2  476fe566d2df676e    2267.0        0.00          1
# 3  f6ad6a1e4d600e0d     203.0       -2.54          0
# 4  1d2d98ddd05b38fb     738.0      -10.16          1
# 5  46e2011d92463b7e    -292.0        5.08          1
# 6  e1d40e8782d80bc2    -336.0        2.54          1
# 7  7d8435c56043b0ae   -1732.0        0.00          0
# 8  ec13c393d029297d    -169.0       -5.08          0
# 9  8f765fd5775a8873    -220.0       -2.54          0
#
# [10 rows x 127 columns]

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import accuracy_score, log_loss
from sklearn.preprocessing import StandardScaler


# Sort Chronologically 
df = df.sort_values(by='date').reset_index(drop=True)

# Features included so far
features = [
    'r_splm', 'r_sapm', 
    'b_splm', 'b_sapm',
    'reach_diff', 'age_diff' 
]
target = 'is_winner' # Binary Variable

# Walk-Forward Validation Setup
start_index = 2000 
batch_size = 500 # We will predict the next 500 fights, then retrain.

predictions = []
actuals = []
probabilities = []

print(f"Starting Walk-Forward Validation on {len(df)} fights...")

for i in range(start_index, len(df), batch_size):
    # Iteration Step - This splits up the data for the Walk-Forward Validation 
    train_data = df.iloc[:i]
    test_data = df.iloc[i : i + batch_size]
    
    if test_data.empty:
        break
        
    X_train = train_data[features]
    y_train = train_data[target]
    
    X_test = test_data[features]
    y_test = test_data[target]
    
    # Model Training
    model = xgb.XGBClassifier(
        n_estimators=100, 
        max_depth=3, 
        learning_rate=0.1, 
        objective='binary:logistic',
        eval_metric='logloss',
        use_label_encoder=False
    )
    
    model.fit(X_train, y_train)
    
    # Predictions on test set
    batch_probs = model.predict_proba(X_test)[:, 1]
    batch_preds = (batch_probs > 0.5).astype(int) # Threshold at 50%
    
    # Storing Results
    probabilities.extend(batch_probs)
    predictions.extend(batch_preds)
    actuals.extend(y_test.values)
    
    print(f"Batch {i//batch_size}: Trained on {len(train_data)} fights, predicted {len(test_data)}")

# Final Evaluation
overall_acc = accuracy_score(actuals, predictions)
overall_logloss = log_loss(actuals, probabilities)

print("\n--- Final Model Performance ---")
print(f"Accuracy: {overall_acc:.2%}") 
print(f"Log Loss: {overall_logloss:.4f}")

# Feature Importance
import matplotlib.pyplot as plt

xgb.plot_importance(model, importance_type='weight')
plt.title("What Drives the Fight Outcome?")
plt.show()
# Out:
# Starting Walk-Forward Validation on 8337 fights...
# Batch 4: Trained on 2000 fights, predicted 500
# Batch 5: Trained on 2500 fights, predicted 500
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Batch 6: Trained on 3000 fights, predicted 500
# Batch 7: Trained on 3500 fights, predicted 500
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Batch 8: Trained on 4000 fights, predicted 500
# Batch 9: Trained on 4500 fights, predicted 500
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Batch 10: Trained on 5000 fights, predicted 500
# Batch 11: Trained on 5500 fights, predicted 500
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Batch 12: Trained on 6000 fights, predicted 500
# Batch 13: Trained on 6500 fights, predicted 500
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Batch 14: Trained on 7000 fights, predicted 500
# Batch 15: Trained on 7500 fights, predicted 500
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\breha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:199: UserWarning: [22:12:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Batch 16: Trained on 8000 fights, predicted 337
#
# --- Final Model Performance ---
# Accuracy: 62.71%
# Log Loss: 0.6512 (Lower is better, <0.69 is edge)

# %%
# Will Charles Oliveira win against Max Holloway in the rematch?
# Step 1: Create Dataset

df_bmf = pd.read_csv("C:\\Users\\breha\\Downloads\\UFC_BMF_DOBRONX_VS_BLESSED.csv")
df_bmf.head(1)
# Out:
#              r_name       r_dob  r_splm  r_sapm        b_name       b_dob  \
# 0  Charles Oliveira  10/17/1989    3.35    3.24  Max Holloway  12/04/1991
#
#    b_splm  b_sapm  reach_diff
# 0     7.2    4.74           5

# %%
#Step 2: Clean data and create features

df_bmf['r_dob'] = pd.to_datetime(df_bmf['r_dob'])
df_bmf['b_dob'] = pd.to_datetime(df_bmf['b_dob'])
df_bmf['age_diff'] = -(df_bmf['r_dob']-df_bmf['b_dob']).dt.days

df_bmf.head(1)

df_bmf['r_dob'] = pd.to_datetime(df_bmf['r_dob'])
df_bmf['b_dob'] = pd.to_datetime(df_bmf['b_dob'])
df_bmf['age_diff'] = (df_bmf['r_dob']-df_bmf['b_dob']).dt.days


df_bmf.drop('r_dob', axis =1, inplace = True)
df_bmf.drop('b_dob', axis = 1, inplace = True)
df_bmf.drop('r_name', axis =1, inplace = True)
df_bmf.drop('b_name', axis =1, inplace = True)

# %%
#Sanity check

X_new = df_bmf
print(X_new)
# Out:
#    r_splm  r_sapm  b_splm  b_sapm  reach_diff  age_diff
# 0    3.35    3.24     7.2    4.74           5      -778

# %%
#Prediction Step
probs = model.predict_proba(X_new)[0]
red_win_prob = probs[1]
blue_win_prob = probs[0]
print(f"\n--- Prediction Result ---")
print(f"Charles Oliveira Win Probability: {red_win_prob:.2%}")
print(f"Max Holloway Win Probability: {blue_win_prob:.2%}")
# Out:
# --- Prediction Result ---
# Charles Oliveira Win Probability: 38.58%
# Max Holloway Win Probability: 61.42%
